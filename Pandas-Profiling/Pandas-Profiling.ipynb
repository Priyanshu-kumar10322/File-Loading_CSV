# %% [markdown]
# # Environment Set-up

# %%
#importing lib.

import pandas as pd
import sys as s

# %% [markdown]
# # Data Wrangling

# %%
# calling the dataset (loading the top 5.head)

df = pd.read_csv(r"C:\Users\Priyanshu\Downloads\train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# checking the version of our python 
s.version
# Out:
# '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# # Installing the requirment for `Pandas-Profiling`

# %% [markdown]
# - Note:
# ⚠️ pandas-profiling package naming was changed. To continue profiling data use ydata-profiling instead!
#
# This repo implements the brownout strategy for deprecating the pandas-profiling package on PyPI.⚠️

# %%
pip install ydata-profiling
# Out:
# ...
#    ---------------------------------------- 0.0/678.1 kB ? eta -:--:--
#    ---------------------------------------- 678.1/678.1 kB 5.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------------- ----------------------- 1.3/3.1 MB 6.2 MB/s eta 0:00:01
#    --------------------------------- ------ 2.6/3.1 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 5.7 MB/s eta 0:00:00
# ...
#
#    --- ------------------------------------  1/12 [filetype]
#    ------ ---------------------------------  2/12 [typeguard]
#   Attempting uninstall: PyYAML
#    ------ ---------------------------------  2/12 [typeguard]
#     Found existing installation: PyYAML 6.0.2
#    ------ ---------------------------------  2/12 [typeguard]
#    ---------- -----------------------------  3/12 [PyYAML]
#     Uninstalling PyYAML-6.0.2:
#    ---------- -----------------------------  3/12 [PyYAML]
#       Successfully uninstalled PyYAML-6.0.2
# ...

# %% [markdown]
# ## Storing all the data information in a HTML file that can easily be accessible

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title="Titanic Dataset Profile")
profile.to_file("output.html")
profile.show()
# Out:
# C:\Users\Priyanshu\AppData\Local\Temp\ipykernel_27636\1000420615.py:2: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please install fg-data-profiling via `pip install fg-data-profiling` and use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 14
#      11 profile.to_file("output.html")
#      13 # Or display in Jupyter Notebook
# ---> 14 profile.show()
#
# AttributeError: 'ProfileReport' object has no attribute 'show'

# %% [markdown]
# all the information sholud be here
# ![image.png](attachment:b1e5f8c9-7275-4ec9-ae52-a5448723c9e9.png)

# %% [markdown]
# some thing like this `Dataset Statistic`
# ![image.png](attachment:2be378a4-9866-4ea3-bb5c-1fea3d6361b0.png)
